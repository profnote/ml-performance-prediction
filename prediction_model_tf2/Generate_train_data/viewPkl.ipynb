# %% [markdown]
# ### View .pkl files

# %%
import os
import pandas as pd
import numpy as np

# %%
path = os.getcwd() + '/results/'
filename = 'benchmark_convolution_GTX850M_20200628.pkl'
df = pd.read_pickle(path + filename)
df
# Out:
#    batchsize  matsize  kernelsize  channels_in  channels_out  strides  \
# 0         52      243           1           15            21        2
# 1         48      472           5            9            17        4
# 2         16      469           4            7            18        3
# 3          4      492           3           16             8        1
# 4         50      214           1           21             1        3
#
#    padding  precision  activation_fct  use_bias  optimizer  gpu  \
# 0        1         32               0     False          0    0
# 1        0         32               1     False          1    0
# 2        0         32               2     False          0    0
# 3        1         32               3     False          5    0
# 4        0         32               2     False          3    0
#
#    timeUsed_median  timeUsed_min  timeUsed_max  timeUsed_std
# 0        24.206033     24.166365     24.326005      0.056497
# ...
