# %% [markdown]
# ### View .pkl files

# %%
import os
import pandas as pd
import numpy as np

# %%
path = os.getcwd() + '/results/'
filename = 'benchmark_convolution_GTX850M_20200708.pkl'
df = pd.read_pickle(path + filename)
df
# Out:
#     batchsize  matsize  kernelsize  channels_in  channels_out  strides  \
# 0          63       51           5           75           142        1
# 1          26      401           6            3            12        3
# 2          56       22           5          120             4        3
# 3          24      272           2            3            24        1
# 4          21      309           2           12            23        4
# ..        ...      ...         ...          ...           ...      ...
# 95         12      480           1            7            15        1
# 96         33        5           1          855          1412        4
# 97          2       50           7          165           155        1
# 98         63      304           7           25             3        3
# 99         14       15           2          264           537        3
#
#     padding  precision  activation_fct  use_bias  optimizer  gpu  \
# ...

# %%
df.isnull().sum()
# Out:
# batchsize           0
# matsize             0
# kernelsize          0
# channels_in         0
# channels_out        0
# strides             0
# padding             0
# precision           0
# activation_fct      0
# use_bias            0
# optimizer           0
# gpu                 0
# timeUsed_median    11
# timeUsed_min       11
# timeUsed_max       11
# timeUsed_std       11
# dtype: int64
